# %% [markdown]
# ## Project 2 - Task 2 (Part A) (IoTA Fall 2016)
# ### Linear Regression Analysis - Single Variable
# #### student_id : *avshirod*

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import linear_model
import scipy.stats as stats
import os

# %%
filename = 'p2.csv'
data = pd.read_csv(filename)
header = list(data.columns.values)
regr = linear_model.LinearRegression()
dirpath = os.getcwd() + "/task2"

# %%
# for val in header[:-1]:
def analyze(val):
    x = data[[val]]
    y = data[['Y']]
    result = smf.ols(formula = "y ~ x", data=data).fit()
    print(result.params)
    print(result.summary())
    
    plt.xlabel(str(val))
    plt.ylabel("Y")
    plt.title("Regression Line for " + str(val) + " vs. Y")
    regr.fit(x,y)
    plt.scatter(x, y,  color='black', alpha = 0.45)
    plt.plot(x, regr.predict(x), color='blue', linewidth=3)
    plt.legend(['Fitted Model LinearRegression', 'Data'])
    plt.show()
    # fig_path_regline = dirpath + "/plots/regline_" + val
    # plt.savefig(fig_path_regline)
    plt.gcf().clear()

    residuals = result.resid_pearson
    qqp = sm.qqplot(residuals, loc=0)
    # fig_path_qqplot = dirpath + "/plots/qqplot_" + val
    plt.xlabel(str(val))
    plt.ylabel("Y")
    plt.title("QQ Plot for Residuals")
    plt.show(qqp)
    # plt.savefig(fig_path_qqplot)
    plt.gcf().clear()

    # pd.DataFrame.hist(residuals)
    plt.hist(list(residuals))
    # fig_path_histres = dirpath + "/plots/histres_" + val
    plt.xlabel(str(val))
    plt.ylabel("Y")
    plt.title("Histogram for Residuals of " + str(val))
    plt.show()
    # plt.savefig(fig_path_histres)
    plt.gcf().clear()
    
    chires = stats.chisquare(residuals)
    print("\nChi Square Test")
    print(chires)
    plt.scatter(list(x1.values.flatten()), list(y.values.flatten()), residuals)
    # fig_path_scatres = dirpath + "/plots/scatres_" + val
    plt.xlabel(str(val))
    plt.ylabel("Y")
    plt.title("ScatterPlot for Residuals of " + str(val))
    plt.show()
    # plt.savefig(fig_path_scatres)
    plt.gcf().clear()
    
    print("Y = {} + {} * {}".format(result.params[0], result.params[1], val))
    print("s^2 (SSE) = {}".format(result.mse_resid))
    print("s^2 (SST) = {}".format(result.mse_total))
    print("R^2 = {}".format(result.rsquared))
    print("F-value = {}".format(result.fvalue))

# %%
analyze('X1')
# Out:
# Intercept   -4.589580
# x            0.230799
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     1473.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):          7.48e-151
# Time:                        21:19:25   Log-Likelihood:                -2493.9
# No. Observations:                 500   AIC:                             4992.
# Df Residuals:                     498   BIC:                             5000.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.5896      3.580     -1.282      0.200       -11.624     2.445
# x              0.2308      0.006     38.374      0.000         0.219     0.243
# ==============================================================================
# Omnibus:                        9.415   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.400
# Skew:                           0.327   Prob(JB):                      0.00910
# Kurtosis:                       3.154   Cond. No.                     1.34e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Chi Square Test
# Power_divergenceResult(statistic=-3.2789365708048339e+17, pvalue=1.0)
# Y = -4.589579847322592 + 0.23079882718231493 * X1
# s^2 (SSE) = 1263.5283770313586
# s^2 (SST) = 4989.674114548346
# R^2 = 0.7472788348323933
# F-value = 1472.5512186512854

# %% [markdown]
# ## **Regression Analysis for X1**
# --------------------------------------------
#
# From above results above,
#
# p-value for *X1* is < 0.05 (value = 0.001). Hence the variable contributes significantly to predicting *Y*.
#
# Value of R^2 is 0.747. That means that model is an okay fit.
# This can be seen from the regression line, as the model categorically under- and over- fits the data.
#
# The p-value of the F-test is very low (close to zero). This reiterates that *X1* does contribute to *Y*.
#
# The Q-Q plot is linear, indicating that residuals are normally distributed.
# The histogram of residuals shows that the residual distribution has mean 0 and a low variance.
# The scatter plot of residuals has a pattern, meaning that the model lacks some accuracy.

# %%
analyze('X2')
# Out:
# Intercept    115.403561
# x              0.897744
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2433
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):              0.622
# Time:                        21:39:15   Log-Likelihood:                -2837.6
# No. Observations:                 500   AIC:                             5679.
# Df Residuals:                     498   BIC:                             5688.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    115.4036      7.063     16.340      0.000       101.527   129.280
# x              0.8977      1.820      0.493      0.622        -2.678     4.474
# ==============================================================================
# Omnibus:                       18.148   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.904
# Skew:                           0.369   Prob(JB):                     0.000352
# Kurtosis:                       2.533   Cond. No.                         9.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chi Square Test
# Power_divergenceResult(statistic=-6.3141683964822822e+17, pvalue=1.0)
# Y = 115.40356146548217 + 0.8977437843344288 * X2
# s^2 (SSE) = 4997.252161618058
# s^2 (SST) = 4989.674114548346
# R^2 = 0.000488305701809133
# F-value = 0.24329504185709147

# %%
analyze('X3')
# Out:
# Intercept    123.835473
# x            -65.086558
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     3.001
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):             0.0838
# Time:                        21:39:23   Log-Likelihood:                -2836.2
# No. Observations:                 500   AIC:                             5676.
# Df Residuals:                     498   BIC:                             5685.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    123.8355      4.400     28.145      0.000       115.191   132.480
# x            -65.0866     37.572     -1.732      0.084      -138.906     8.733
# ==============================================================================
# Omnibus:                       16.541   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               14.997
# Skew:                           0.365   Prob(JB):                     0.000554
# Kurtosis:                       2.568   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chi Square Test
# Power_divergenceResult(statistic=2.2979432524902743e+18, pvalue=0.0)
# Y = 123.835472974561 + -65.08655840590416 * X3
# s^2 (SSE) = 4969.74609628647
# s^2 (SST) = 4989.674114548346
# R^2 = 0.005989855968616231
# F-value = 3.00092337113687

# %%
analyze('X4')
# Out:
# Intercept    118.687931
# x             -0.058782
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.005292
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):              0.942
# Time:                        21:39:27   Log-Likelihood:                -2837.7
# No. Observations:                 500   AIC:                             5679.
# Df Residuals:                     498   BIC:                             5688.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    118.6879      3.925     30.235      0.000       110.975   126.400
# x             -0.0588      0.808     -0.073      0.942        -1.646     1.529
# ==============================================================================
# Omnibus:                       18.190   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.743
# Skew:                           0.364   Prob(JB):                     0.000381
# Kurtosis:                       2.526   Cond. No.                         6.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chi Square Test
# Power_divergenceResult(statistic=-3.2751060374277261e+17, pvalue=1.0)
# Y = 118.68793071965239 + -0.05878156371268872 * X4
# s^2 (SSE) = 4999.640416201881
# s^2 (SST) = 4989.674114548346
# R^2 = 1.0625507116057697e-05
# F-value = 0.005291558769290297

# %%
analyze('X5')
# Out:
# Intercept    72.371897
# x            17.234188
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     1073.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):          2.56e-126
# Time:                        21:39:48   Log-Likelihood:                -2550.6
# No. Observations:                 500   AIC:                             5105.
# Df Residuals:                     498   BIC:                             5114.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     72.3719      2.270     31.875      0.000        67.911    76.833
# x             17.2342      0.526     32.754      0.000        16.200    18.268
# ==============================================================================
# Omnibus:                        2.892   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.235   Jarque-Bera (JB):                2.780
# Skew:                          -0.182   Prob(JB):                        0.249
# Kurtosis:                       3.034   Cond. No.                         5.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chi Square Test
# Power_divergenceResult(statistic=3.3374890095692058e+18, pvalue=0.0)
# Y = 72.37189711956465 + 17.234187546887053 * X5
# s^2 (SSE) = 1585.045134555748
# s^2 (SST) = 4989.674114548346
# R^2 = 0.6829715418111002
# F-value = 1072.8368985072918
